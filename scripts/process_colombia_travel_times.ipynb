# %% [markdown]
# # Modules

# %%
import pandas as pd
from io import StringIO
import numpy as np
import time
import re
import os

import requests
import json
import concurrent.futures

# %% [markdown]
# # Variables

# %%
api_key = "AIzaSyB__u8A0uJ-5mvf_7gdNE6RFGpdTdVIV_k" 
output_files = '../data/raw_data'

ipums_processed_file = f'ipums_relation_processed.csv'

######################
## Create directories
######################
directory = f'{output_files}/tmp'
if not os.path.exists(directory):
    os.makedirs(directory)
    print("Directory '%s' created" %directory)

# %% [markdown]
# # Functions

# %%
def get_distance_matrix(origins, destinations, mode="driving", api_key="--"):
    # Base URL for the Distance Matrix API
    base_url = "https://maps.googleapis.com/maps/api/distancematrix/json"

    # Parameters for the API
    params = {
        "origins": "|".join(origins),
        "destinations": "|".join(destinations),
        "mode": mode,
        "key": api_key
    }

    # Make the API request
    response = requests.get(base_url, params=params)

    # Check for a successful response
    if response.status_code == 200:
        return response.json()
    else:
        return None

def get_duration_in_minutes(duration_seconds):
    return round(duration_seconds / 60)

# %%
def retriable_get_distance_matrix(origin, destination, mode, api_key, max_retries=5):
    retry_count = 0
    while retry_count <= max_retries:
        try:
            return get_distance_matrix(origin, destination, mode=mode, api_key=api_key)
        except:
            # Here we assume that any exception indicates a failure.
            # You might want to catch more specific exceptions depending on the nature of your failures.
            if retry_count < max_retries:
                sleep_time = (2 ** retry_count) * 0.1  # exponential backoff starting with 100ms
                time.sleep(sleep_time)
                retry_count += 1
            else:
                raise  # Re-raise the exception after max_retries

# %% [markdown]
# # Load info

# %%
df_mun_list = (pd.read_csv(ipums_processed_file)[['divipola', 'MUN', 'DPTO']]
                                                                            .drop_duplicates()
                                                                            .rename(columns={'divipola':'CODE'}))

df_mun_list['DPTO']  = df_mun_list['DPTO'].str.title()
df_mun_list['MUN']   = df_mun_list['MUN'].str.title()

df_mun_list['FULL_NAME'] = df_mun_list['MUN'] + ', ' + df_mun_list['DPTO']
get_code = df_mun_list.set_index('FULL_NAME')['CODE'].to_dict()

# %% [markdown]
# # Get distance and time info

# %%
modes = ["driving", "walking"]  # Add other modes as needed

for departamento in np.unique(df_mun_list.DPTO):
    print(f'**** Processing departamento : {departamento}')
    df_mun_partial = df_mun_list[df_mun_list.DPTO == departamento]

    codigo_departamento = np.unique(df_mun_partial.CODE.astype(str).str[:-3])[0]

    origins      = df_mun_partial['FULL_NAME'].to_list()
    destinations = df_mun_partial['FULL_NAME'].to_list()

    def process_origin(origin):
        local_data = {
            'Origin': [],
            'Destination': [],
        }
        for mode in modes:
            local_data[f'Distance_{mode}'] = []
            local_data[f'Time_minutes_{mode}'] = []

        print(f'--> Origin : {origin}')
        for destination in destinations:
            local_data['Origin'].append(origin)
            local_data['Destination'].append(destination)

            for mode in modes:
                result = retriable_get_distance_matrix([origin], [destination], mode, api_key)
                #result = get_distance_matrix([origin], [destination], mode=mode, api_key=api_key)

                if result and result['status'] == 'OK':
                    element = result['rows'][0]['elements'][0]

                    if element['status'] == 'OK':
                        distance = element['distance']['text']
                        duration_seconds = element['duration']['value']
                        duration_minutes = get_duration_in_minutes(duration_seconds)

                        local_data[f'Distance_{mode}'].append(distance)
                        local_data[f'Time_minutes_{mode}'].append(duration_minutes)
                    else:
                        local_data[f'Distance_{mode}'].append(None)
                        local_data[f'Time_minutes_{mode}'].append(None)

                else:
                    local_data[f'Distance_{mode}'].append(None)
                    local_data[f'Time_minutes_{mode}'].append(None)

        return local_data

    data = {
        'Origin': [],
        'Destination': [],
    }

    for mode in modes:
        data[f'Distance_{mode}'] = []
        data[f'Time_minutes_{mode}'] = []

    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = [executor.submit(process_origin, origin) for origin in origins]
        
        for future in concurrent.futures.as_completed(futures):
            local_data = future.result()
            for key, values in local_data.items():
                data[key].extend(values)

    df = pd.DataFrame(data)
    df['Code_Origin'] = df['Origin'].map(get_code)
    df['Code_Destination'] = df['Destination'].map(get_code)

    df.to_csv(f'{output_files}/tmp/tmp_departamento_{codigo_departamento}_travel_info.csv', index=False)
    print(f'\n')
# Out:
# **** Processing departamento : Amazonas
# --> Origin : Leticia, Amazonas
# --> Origin : El Encanto, Amazonas
# --> Origin : La Chorrera, Amazonas
# --> Origin : Puerto Arica, Amazonas
# --> Origin : La Pedrera, Amazonas
# --> Origin : Mirití - Paraná, Amazonas
# --> Origin : Puerto Nariño, Amazonas
# --> Origin : Puerto Santander, Amazonas
# --> Origin : Tarapacá, Amazonas
# --> Origin : La Victoria, Amazonas
# --> Origin : Puerto Alegría, Amazonas
#
#
# **** Processing departamento : Antioquia
# --> Origin : Medellín, Antioquia
# --> Origin : Abejorral, Antioquia
# --> Origin : La Unión, Antioquia
# --> Origin : Amagá, Antioquia
# --> Origin : Andes, Antioquia
# --> Origin : Apartadó, Antioquia
# --> Origin : Arboletes, Antioquia
# --> Origin : San Juan De Urabá, Antioquia
# --> Origin : Barbosa, Antioquia
# --> Origin : Bello, Antioquia
# --> Origin : Betania, Antioquia
# --> Origin : Ciudad Bolívar, Antioquia
# --> Origin : Caldas, Antioquia
# --> Origin : Carepa, Antioquia
# --> Origin : El Carmen De Viboral, Antioquia
# --> Origin : Caucasia, Antioquia
# --> Origin : Chigorodó, Antioquia
# --> Origin : Concordia, Antioquia
# --> Origin : Copacabana, Antioquia
# --> Origin : Dabeiba, Antioquia
# --> Origin : Mutatá, Antioquia
# --> Origin : El Bagre, Antioquia
# --> Origin : Nechí, Antioquia
# --> Origin : Envigado, Antioquia
# --> Origin : Fredonia, Antioquia
# --> Origin : Frontino, Antioquia
# --> Origin : Murindó, Antioquia
# --> Origin : Vigía Del Fuerte, Antioquia
# --> Origin : Girardota, Antioquia
# --> Origin : Guarne, Antioquia
# --> Origin : Itagüí, Antioquia
# --> Origin : Ituango, Antioquia
# --> Origin : La Ceja, Antioquia
# --> Origin : La Estrella, Antioquia
# --> Origin : Marinilla, Antioquia
# --> Origin : Necoclí, Antioquia
# --> Origin : Puerto Berrío, Antioquia
# --> Origin : Rionegro, Antioquia
# --> Origin : Sabaneta, Antioquia
# --> Origin : San Carlos, Antioquia
# --> Origin : San Pedro De Urabá, Antioquia
# --> Origin : San Vicente Ferrer, Antioquia
# --> Origin : Donmatías, Antioquia
# --> Origin : Entrerríos, Antioquia
# --> Origin : San Pedro De Los Milagros, Antioquia
#
#
# **** Processing departamento : Arauca
# --> Origin : Arauca, Arauca
# --> Origin : Cravo Norte, Arauca
# --> Origin : Arauquita, Arauca
# --> Origin : Fortul, Arauca
# --> Origin : Saravena, Arauca
# --> Origin : Puerto Rondón, Arauca
# --> Origin : Tame, Arauca
#
#
# **** Processing departamento : Archipiélago De San Andrés Providencia Y
# --> Origin : San Andrés, Archipiélago De San Andrés Providencia Y
# --> Origin : Providencia, Archipiélago De San Andrés Providencia Y
#
#
# **** Processing departamento : Atlántico
# --> Origin : Barranquilla, Atlántico
# --> Origin : Baranoa, Atlántico
# --> Origin : Campo De La Cruz, Atlántico
# --> Origin : Malambo, Atlántico
# --> Origin : Puerto Colombia, Atlántico
# --> Origin : Sabanalarga, Atlántico
# --> Origin : Santo Tomás, Atlántico
# --> Origin : Soledad, Atlántico
# --> Origin : Galapa, Atlántico
# --> Origin : Tubará, Atlántico
# --> Origin : Usiacurí, Atlántico
# --> Origin : Juan De Acosta, Atlántico
# --> Origin : Piojó, Atlántico
# --> Origin : Polonuevo, Atlántico
# --> Origin : Sabanagrande, Atlántico
# --> Origin : Palmar De Varela, Atlántico
# --> Origin : Ponedera, Atlántico
# --> Origin : Candelaria, Atlántico
# --> Origin : Manatí, Atlántico
# --> Origin : Santa Lucía, Atlántico
# --> Origin : Suan, Atlántico
# --> Origin : Luruaco, Atlántico
# --> Origin : Repelón, Atlántico
#
#
# **** Processing departamento : Bogotá D.C.
# --> Origin : Bogotá D.C., Bogotá D.C.
#
#
# **** Processing departamento : Bolívar
# --> Origin : Cartagena De Indias, Bolívar
# --> Origin : Achí, Bolívar
# --> Origin : Montecristo, Bolívar
# --> Origin : San Jacinto Del Cauca, Bolívar
# --> Origin : Arjona, Bolívar
# --> Origin : Calamar, Bolívar
# --> Origin : El Guamo, Bolívar
# --> Origin : El Carmen De Bolívar, Bolívar
# --> Origin : Magangué, Bolívar
# --> Origin : María La Baja, Bolívar
# --> Origin : Mompós, Bolívar
# --> Origin : Morales, Bolívar
# --> Origin : Arenal, Bolívar
# --> Origin : Pinillos, Bolívar
# --> Origin : Tiquisio, Bolívar
# --> Origin : Río Viejo, Bolívar
# --> Origin : Regidor, Bolívar
# --> Origin : San Jacinto, Bolívar
# --> Origin : San Juan Nepomuceno, Bolívar
# --> Origin : San Martín De Loba, Bolívar
# --> Origin : El Peñón, Bolívar
# --> Origin : Hatillo De Loba, Bolívar
# --> Origin : San Pablo, Bolívar
# --> Origin : Cantagallo, Bolívar
# --> Origin : Simití, Bolívar
# --> Origin : Santa Rosa Del Sur, Bolívar
# --> Origin : Talaigua Nuevo, Bolívar
# --> Origin : Cicuco, Bolívar
# --> Origin : Turbaco, Bolívar
# --> Origin : Turbaná, Bolívar
# --> Origin : Clemencia, Bolívar
# --> Origin : Santa Catalina, Bolívar
# --> Origin : Santa Rosa, Bolívar
# --> Origin : San Estanislao, Bolívar
# --> Origin : Villanueva, Bolívar
# --> Origin : Mahates, Bolívar
# --> Origin : Arroyohondo, Bolívar
# --> Origin : Soplaviento, Bolívar
# --> Origin : San Cristóbal, Bolívar
# --> Origin : Córdoba, Bolívar
# --> Origin : Zambrano, Bolívar
# --> Origin : Barranco De Loba, Bolívar
# --> Origin : Altos Del Rosario, Bolívar
# --> Origin : Margarita, Bolívar
# --> Origin : San Fernando, Bolívar
# --> Origin : Norosí, Bolívar
#
#
# **** Processing departamento : Boyacá
# --> Origin : Tunja, Boyacá
# --> Origin : Chiquinquirá, Boyacá
# --> Origin : Duitama, Boyacá
# --> Origin : Moniquirá, Boyacá
# --> Origin : Paipa, Boyacá
# --> Origin : Puerto Boyacá, Boyacá
# --> Origin : Sogamoso, Boyacá
# --> Origin : Chiscas, Boyacá
# --> Origin : Cubará, Boyacá
# --> Origin : Güicán, Boyacá
# --> Origin : El Cocuy, Boyacá
# --> Origin : El Espino, Boyacá
# --> Origin : Guacamayas, Boyacá
# --> Origin : Panqueba, Boyacá
# --> Origin : San Mateo, Boyacá
# --> Origin : Covarachía, Boyacá
# --> Origin : Soatá, Boyacá
# --> Origin : Tipacoque, Boyacá
# --> Origin : Boavita, Boyacá
# --> Origin : La Uvita, Boyacá
# --> Origin : Jericó, Boyacá
# --> Origin : Chita, Boyacá
# --> Origin : Socotá, Boyacá
# --> Origin : Sativanorte, Boyacá
# --> Origin : Sativasur, Boyacá
# --> Origin : Susacón, Boyacá
# --> Origin : Belén, Boyacá
# --> Origin : Tutazá, Boyacá
# --> Origin : Paz De Río, Boyacá
# --> Origin : Socha, Boyacá
# --> Origin : Tasco, Boyacá
# --> Origin : Aquitania, Boyacá
# --> Origin : Labranzagrande, Boyacá
# --> Origin : Pajarito, Boyacá
# --> Origin : Paya, Boyacá
# --> Origin : Pisba, Boyacá
# --> Origin : Busbanzá, Boyacá
# --> Origin : Gámeza, Boyacá
# --> Origin : Mongua, Boyacá
# --> Origin : Monguí, Boyacá
# --> Origin : Tópaga, Boyacá
# --> Origin : Corrales, Boyacá
# --> Origin : Betéitiva, Boyacá
# --> Origin : Cerinza, Boyacá
# --> Origin : Floresta, Boyacá
# --> Origin : Santa Rosa De Viterbo, Boyacá
# --> Origin : Cuítiva, Boyacá
# --> Origin : Firavitoba, Boyacá
# --> Origin : Iza, Boyacá
# --> Origin : Nobsa, Boyacá
# --> Origin : Tibasosa, Boyacá
# --> Origin : Pesca, Boyacá
# --> Origin : Tota, Boyacá
# --> Origin : Zetaquira, Boyacá
# --> Origin : Cómbita, Boyacá
# --> Origin : Oicatá, Boyacá
# --> Origin : Sotaquirá, Boyacá
# --> Origin : Chivatá, Boyacá
# --> Origin : Toca, Boyacá
# --> Origin : Tuta, Boyacá
# --> Origin : Siachoque, Boyacá
# --> Origin : Soracá, Boyacá
# --> Origin : Ciénega, Boyacá
# --> Origin : Rondón, Boyacá
# --> Origin : Viracachá, Boyacá
# --> Origin : Berbeo, Boyacá
# --> Origin : Campohermoso, Boyacá
# --> Origin : Miraflores, Boyacá
# --> Origin : Páez, Boyacá
# --> Origin : San Eduardo, Boyacá
# --> Origin : Chivor, Boyacá
# --> Origin : Guayatá, Boyacá
# --> Origin : San Luis De Gaceno, Boyacá
# --> Origin : Santa María, Boyacá
# --> Origin : Almeida, Boyacá
# --> Origin : Garagoa, Boyacá
# --> Origin : Macanal, Boyacá
# --> Origin : Guateque, Boyacá
# --> Origin : Somondoco, Boyacá
# --> Origin : Sutatenza, Boyacá
# --> Origin : Tenza, Boyacá
# --> Origin : Chinavita, Boyacá
# --> Origin : La Capilla, Boyacá
# --> Origin : Pachavita, Boyacá
# --> Origin : Úmbita, Boyacá
# --> Origin : Boyacá, Boyacá
# --> Origin : Nuevo Colón, Boyacá
# --> Origin : Jenesano, Boyacá
# --> Origin : Tibaná, Boyacá
# --> Origin : Ramiriquí, Boyacá
# --> Origin : Ventaquemada, Boyacá
# --> Origin : Turmequé, Boyacá
# --> Origin : Cucaita, Boyacá
# --> Origin : Chíquiza, Boyacá
# --> Origin : Motavita, Boyacá
# --> Origin : Samacá, Boyacá
# --> Origin : Sora, Boyacá
# --> Origin : Ráquira, Boyacá
# --> Origin : Arcabuco, Boyacá
# --> Origin : Gachantivá, Boyacá
# --> Origin : Villa De Leyva, Boyacá
# --> Origin : Sáchica, Boyacá
# --> Origin : Santa Sofía, Boyacá
# --> Origin : Chitaraque, Boyacá
# --> Origin : San José De Pare, Boyacá
# --> Origin : Santana, Boyacá
# --> Origin : Togüí, Boyacá
# --> Origin : Saboyá, Boyacá
# --> Origin : San Miguel De Sema, Boyacá
# --> Origin : Sutamarchán, Boyacá
# --> Origin : Tinjacá, Boyacá
# --> Origin : Buenavista, Boyacá
# --> Origin : Caldas, Boyacá
# --> Origin : Coper, Boyacá
# --> Origin : Maripí, Boyacá
# --> Origin : Muzo, Boyacá
# --> Origin : Briceño, Boyacá
# --> Origin : Pauna, Boyacá
# --> Origin : San Pablo De Borbur, Boyacá
# --> Origin : Tununguá, Boyacá
# --> Origin : La Victoria, Boyacá
# --> Origin : Otanche, Boyacá
# --> Origin : Quípama, Boyacá
#
#
# **** Processing departamento : Caldas
# --> Origin : Manizales, Caldas
# --> Origin : Aguadas, Caldas
# --> Origin : Anserma, Caldas
# --> Origin : Chinchiná, Caldas
# --> Origin : La Dorada, Caldas
# --> Origin : Manzanares, Caldas
# --> Origin : Neira, Caldas
# --> Origin : Palestina, Caldas
# --> Origin : Pensilvania, Caldas
# --> Origin : Riosucio, Caldas
# --> Origin : Marulanda, Caldas
# --> Origin : Salamina, Caldas
# --> Origin : Samaná, Caldas
# --> Origin : Norcasia, Caldas
# --> Origin : Marmato, Caldas
# --> Origin : Supía, Caldas
# --> Origin : Villamaría, Caldas
# --> Origin : Marquetalia, Caldas
# --> Origin : Victoria, Caldas
# --> Origin : La Merced, Caldas
# --> Origin : Pácora, Caldas
# --> Origin : Filadelfia, Caldas
# --> Origin : Aranzazu, Caldas
# --> Origin : Belalcázar, Caldas
# --> Origin : Risaralda, Caldas
# --> Origin : San José, Caldas
# --> Origin : Viterbo, Caldas
#
#
# **** Processing departamento : Caquetá
# --> Origin : Florencia, Caquetá
# --> Origin : Cartagena Del Chairá, Caquetá
# --> Origin : El Doncello, Caquetá
# --> Origin : Puerto Rico, Caquetá
# --> Origin : San Vicente Del Caguán, Caquetá
# --> Origin : Valparaíso, Caquetá
# --> Origin : Solita, Caquetá
# --> Origin : Curillo, Caquetá
# --> Origin : San José Del Fragua, Caquetá
# --> Origin : Albania, Caquetá
# --> Origin : Belén De Los Andaquíes, Caquetá
# --> Origin : Morelia, Caquetá
# --> Origin : Solano, Caquetá
# --> Origin : Milán, Caquetá
# --> Origin : El Paujíl, Caquetá
# --> Origin : La Montañita, Caquetá
#
#
# **** Processing departamento : Casanare
# --> Origin : Yopal, Casanare
# --> Origin : Hato Corozal, Casanare
# --> Origin : Paz De Ariporo, Casanare
# --> Origin : La Salina, Casanare
# --> Origin : Pore, Casanare
# --> Origin : Támara, Casanare
# --> Origin : Nunchía, Casanare
# --> Origin : Trinidad, Casanare
# --> Origin : Sácama, Casanare
# --> Origin : Aguazul, Casanare
# --> Origin : Maní, Casanare
# --> Origin : Orocué, Casanare
# --> Origin : Recetor, Casanare
# --> Origin : San Luis De Palenque, Casanare
# --> Origin : Chámeza, Casanare
# --> Origin : Monterrey, Casanare
# --> Origin : Sabanalarga, Casanare
# --> Origin : Tauramena, Casanare
# --> Origin : Villanueva, Casanare
#
#
# **** Processing departamento : Cauca
# --> Origin : Popayán, Cauca
# --> Origin : Bolívar, Cauca
# --> Origin : Sucre, Cauca
# --> Origin : Cajibío, Cauca
# --> Origin : Caldono, Cauca
# --> Origin : Padilla, Cauca
# --> Origin : Caloto, Cauca
# --> Origin : El Tambo, Cauca
# --> Origin : Guapí, Cauca
# --> Origin : Almaguer, Cauca
# --> Origin : La Vega, Cauca
# --> Origin : Morales, Cauca
# --> Origin : Páez, Cauca
# --> Origin : Patía, Cauca
# --> Origin : Piendamó, Cauca
# --> Origin : Puerto Tejada, Cauca
# --> Origin : Santander De Quilichao, Cauca
# --> Origin : Villa Rica, Cauca
# --> Origin : Silvia, Cauca
# --> Origin : Suárez, Cauca
# --> Origin : Timbío, Cauca
# --> Origin : Timbiquí, Cauca
# --> Origin : López De Micay, Cauca
# --> Origin : Buenos Aires, Cauca
# --> Origin : Corinto, Cauca
# --> Origin : Miranda, Cauca
# --> Origin : Toribío, Cauca
# --> Origin : Puracé, Cauca
# --> Origin : Inzá, Cauca
# --> Origin : Totoró, Cauca
# --> Origin : La Sierra, Cauca
# --> Origin : Rosas, Cauca
# --> Origin : Sotara, Cauca
# --> Origin : Argelia, Cauca
# --> Origin : Balboa, Cauca
# --> Origin : Florencia, Cauca
# --> Origin : Mercaderes, Cauca
# --> Origin : San Sebastián, Cauca
# --> Origin : Santa Rosa, Cauca
# --> Origin : Piamonte, Cauca
# --> Origin : Guachené, Cauca
# --> Origin : Jambaló, Cauca
#
#
# **** Processing departamento : Cesar
# --> Origin : Valledupar, Cesar
# --> Origin : Pueblo Bello, Cesar
# --> Origin : Aguachica, Cesar
# --> Origin : Agustín Codazzi, Cesar
# --> Origin : Bosconia, Cesar
# --> Origin : Chimichagua, Cesar
# --> Origin : Chiriguaná, Cesar
# --> Origin : Curumaní, Cesar
# --> Origin : El Copey, Cesar
# --> Origin : Becerril, Cesar
# --> Origin : La Jagua De Ibirico, Cesar
# --> Origin : Manaure Balcón Del Cesar, Cesar
# --> Origin : La Paz, Cesar
# --> Origin : San Diego, Cesar
# --> Origin : Astrea, Cesar
# --> Origin : El Paso, Cesar
# --> Origin : Pailitas, Cesar
# --> Origin : Tamalameque, Cesar
# --> Origin : Gamarra, Cesar
# --> Origin : La Gloria, Cesar
# --> Origin : Pelaya, Cesar
# --> Origin : González, Cesar
# --> Origin : Río De Oro, Cesar
# --> Origin : San Alberto, Cesar
# --> Origin : San Martín, Cesar
#
#
# **** Processing departamento : Chocó
# --> Origin : Quibdó, Chocó
# --> Origin : Atrato, Chocó
# --> Origin : Medio Atrato, Chocó
# --> Origin : Río Quito, Chocó
# --> Origin : Bajo Baudó, Chocó
# --> Origin : Medio Baudó, Chocó
# --> Origin : Istmina, Chocó
# --> Origin : El Cantón Del San Pablo, Chocó
# --> Origin : Medio San Juan, Chocó
# --> Origin : Unión Panamericana, Chocó
# --> Origin : Riosucio, Chocó
# --> Origin : Carmen Del Darién, Chocó
# --> Origin : Tadó, Chocó
# --> Origin : Cértegui, Chocó
# --> Origin : Río Iró, Chocó
# --> Origin : Nuquí, Chocó
# --> Origin : Alto Baudó, Chocó
# --> Origin : Bagadó, Chocó
# --> Origin : El Carmen De Atrato, Chocó
# --> Origin : Lloró, Chocó
# --> Origin : Condoto, Chocó
# --> Origin : Nóvita, Chocó
# --> Origin : El Litoral Del San Juan, Chocó
# --> Origin : San José Del Palmar, Chocó
# --> Origin : Sipí, Chocó
# --> Origin : Acandí, Chocó
# --> Origin : Unguía, Chocó
# --> Origin : Bahía Solano, Chocó
# --> Origin : Bojayá, Chocó
# --> Origin : Juradó, Chocó
#
#
# **** Processing departamento : Cundinamarca
# --> Origin : Cajicá, Cundinamarca
# --> Origin : Chía, Cundinamarca
# --> Origin : Facatativá, Cundinamarca
# --> Origin : Funza, Cundinamarca
# --> Origin : Fusagasugá, Cundinamarca
# --> Origin : Girardot, Cundinamarca
# --> Origin : Guaduas, Cundinamarca
# --> Origin : Madrid, Cundinamarca
# --> Origin : Mosquera, Cundinamarca
# --> Origin : Pacho, Cundinamarca
# --> Origin : Sibaté, Cundinamarca
# --> Origin : Soacha, Cundinamarca
# --> Origin : Granada, Cundinamarca
# --> Origin : Villa De San Diego De Ubaté, Cundinamarca
# --> Origin : Villeta, Cundinamarca
# --> Origin : Zipaquirá, Cundinamarca
# --> Origin : Yacopí, Cundinamarca
# --> Origin : Puerto Salgar, Cundinamarca
# --> Origin : Caparrapí, Cundinamarca
# --> Origin : Útica, Cundinamarca
# --> Origin : La Palma, Cundinamarca
# --> Origin : La Peña, Cundinamarca
# --> Origin : El Peñón, Cundinamarca
# --> Origin : Paime, Cundinamarca
# --> Origin : Rivera, Huila
# --> Origin : Hobo, Huila
# --> Origin : Íquira, Huila
# --> Origin : Yaguará, Huila
# --> Origin : Teruel, Huila
# --> Origin : Gigante, Huila
# --> Origin : Nátaga, Huila
# --> Origin : Tesalia, Huila
# --> Origin : Agrado, Huila
# --> Origin : Altamira, Huila
# --> Origin : Pital, Huila
# --> Origin : Paicol, Huila
# --> Origin : La Argentina, Huila
# --> Origin : Tarqui, Huila
# --> Origin : Suaza, Huila
# --> Origin : Timaná, Huila
# --> Origin : Guadalupe, Huila
# --> Origin : Elías, Huila
# --> Origin : Isnos, Huila
# --> Origin : Oporapa, Huila
# --> Origin : Saladoblanco, Huila
# --> Origin : Acevedo, Huila
# --> Origin : Palestina, Huila
#
#
# **** Processing departamento : La Guajira
# --> Origin : Riohacha, La Guajira
# --> Origin : Dibulla, La Guajira
# --> Origin : Barrancas, La Guajira
# --> Origin : Hatonuevo, La Guajira
# --> Origin : Fonseca, La Guajira
# --> Origin : Distracción, La Guajira
# --> Origin : Maicao, La Guajira
# --> Origin : Albania, La Guajira
# --> Origin : Manaure, La Guajira
# --> Origin : San Juan Del Cesar, La Guajira
# --> Origin : Uribia, La Guajira
# --> Origin : El Molino, La Guajira
# --> Origin : Urumita, La Guajira
# --> Origin : La Jagua Del Pilar, La Guajira
# --> Origin : Villanueva, La Guajira
#
#
# **** Processing departamento : Magdalena
# --> Origin : Santa Marta, Magdalena
# --> Origin : Aracataca, Magdalena
# --> Origin : El Retén, Magdalena
# --> Origin : Ariguaní, Magdalena
# --> Origin : Ciénaga, Magdalena
# --> Origin : Zona Bananera, Magdalena
# --> Origin : El Banco, Magdalena
# --> Origin : Fundación, Magdalena
# --> Origin : Algarrobo, Magdalena
# --> Origin : Pivijay, Magdalena
# --> Origin : Plato, Magdalena
# --> Origin : Nueva Granada, Magdalena
# --> Origin : Sabanas De San Ángel, Magdalena
# --> Origin : Santa Bárbara De Pinto, Magdalena
# --> Origin : San Zenón, Magdalena
# --> Origin : Santa Ana, Magdalena
# --> Origin : Pijiño Del Carmen, Magdalena
# --> Origin : Puebloviejo, Magdalena
# --> Origin : Sitionuevo, Magdalena
# --> Origin : El Piñón, Magdalena
# --> Origin : Zapayán, Magdalena
# --> Origin : Remolino, Magdalena
# --> Origin : Salamina, Magdalena
# --> Origin : Cerro De San Antonio, Magdalena
# --> Origin : Pedraza, Magdalena
# --> Origin : Concordia, Magdalena
# --> Origin : Chivolo, Magdalena
# --> Origin : Tenerife, Magdalena
# --> Origin : Guamal, Magdalena
# --> Origin : San Sebastián De Buenavista, Magdalena
#
#
# **** Processing departamento : Meta
# --> Origin : Villavicencio, Meta
# --> Origin : Acacías, Meta
# --> Origin : Granada, Meta
# --> Origin : Puerto López, Meta
# --> Origin : Mesetas, Meta
# --> Origin : La Macarena, Meta
# --> Origin : Uribe, Meta
# --> Origin : Puerto Rico, Meta
# --> Origin : Vistahermosa, Meta
# --> Origin : Mapiripán, Meta
# --> Origin : Puerto Concordia, Meta
# --> Origin : Puerto Lleras, Meta
# --> Origin : Puerto Gaitán, Meta
# --> Origin : San Martín, Meta
# --> Origin : Barranca De Upía, Meta
# --> Origin : Cabuyaro, Meta
# --> Origin : Cumaral, Meta
# --> Origin : El Calvario, Meta
# --> Origin : Restrepo, Meta
# --> Origin : San Juanito, Meta
# --> Origin : Fuente De Oro, Meta
# --> Origin : Lejanías, Meta
# --> Origin : San Juan De Arama, Meta
# --> Origin : Castilla La Nueva, Meta
# --> Origin : Cubarral, Meta
# --> Origin : El Castillo, Meta
# --> Origin : El Dorado, Meta
# --> Origin : Guamal, Meta
# --> Origin : San Carlos De Guaroa, Meta
#
#
# **** Processing departamento : Nariño
# --> Origin : Pasto, Nariño
# --> Origin : Nariño, Nariño
# --> Origin : Barbacoas, Nariño
# --> Origin : Cumbal, Nariño
# --> Origin : El Tambo, Nariño
# --> Origin : El Peñol, Nariño
# --> Origin : Guaitarilla, Nariño
# --> Origin : Ipiales, Nariño
# --> Origin : La Unión, Nariño
# --> Origin : La Tola, Nariño
# --> Origin : Olaya Herrera, Nariño
# --> Origin : Samaniego, Nariño
# --> Origin : Sandoná, Nariño
# --> Origin : San Andrés De Tumaco, Nariño
# --> Origin : Túquerres, Nariño
# --> Origin : Mosquera, Nariño
# --> Origin : Magüí, Nariño
# --> Origin : Francisco Pizarro, Nariño
# --> Origin : Roberto Payán, Nariño
# --> Origin : El Charco, Nariño
# --> Origin : Santa Bárbara, Nariño
# --> Origin : El Rosario, Nariño
# --> Origin : Leiva, Nariño
# --> Origin : Cumbitara, Nariño
# --> Origin : Policarpa, Nariño
# --> Origin : Los Andes, Nariño
# --> Origin : La Llanada, Nariño
# --> Origin : Linares, Nariño
# --> Origin : Mallama, Nariño
# --> Origin : Ricaurte, Nariño
# --> Origin : Sapuyes, Nariño
# --> Origin : Providencia, Nariño
# --> Origin : Santacruz, Nariño
# --> Origin : Aldana, Nariño
# --> Origin : Guachucal, Nariño
# --> Origin : Cuaspúd, Nariño
# --> Origin : Contadero, Nariño
# --> Origin : Pupiales, Nariño
# --> Origin : Gualmatán, Nariño
# --> Origin : Iles, Nariño
# --> Origin : Ospina, Nariño
# --> Origin : Imués, Nariño
# --> Origin : Tangua, Nariño
# --> Origin : Yacuanquer, Nariño
# --> Origin : Ancuyá, Nariño
# --> Origin : La Florida, Nariño
# --> Origin : Consacá, Nariño
# --> Origin : Funes, Nariño
# --> Origin : Puerres, Nariño
# --> Origin : Potosí, Nariño
# --> Origin : Córdoba, Nariño
# --> Origin : Arboleda, Nariño
# --> Origin : Buesaco, Nariño
# --> Origin : San Lorenzo, Nariño
# --> Origin : San Pedro De Cartago, Nariño
# --> Origin : Chachagüí, Nariño
# --> Origin : Taminango, Nariño
# --> Origin : Belén, Nariño
# --> Origin : Colón, Nariño
# --> Origin : San Bernardo, Nariño
# --> Origin : La Cruz, Nariño
# --> Origin : San Pablo, Nariño
# --> Origin : Albán, Nariño
# --> Origin : El Tablón De Gómez, Nariño
#
#
# **** Processing departamento : Norte De Santander
# --> Origin : Buenaventura, Valle Del Cauca
# --> Origin : Guadalajara De Buga, Valle Del Cauca
# --> Origin : Bugalagrande, Valle Del Cauca
# --> Origin : Caicedonia, Valle Del Cauca
# --> Origin : Candelaria, Valle Del Cauca
# --> Origin : Alcalá, Valle Del Cauca
# --> Origin : Cartago, Valle Del Cauca
# --> Origin : Ulloa, Valle Del Cauca
# --> Origin : Dagua, Valle Del Cauca
# --> Origin : La Cumbre, Valle Del Cauca
# --> Origin : El Cerrito, Valle Del Cauca
# --> Origin : Florida, Valle Del Cauca
# --> Origin : Guacarí, Valle Del Cauca
# --> Origin : Ginebra, Valle Del Cauca
# --> Origin : Jamundí, Valle Del Cauca
# --> Origin : La Unión, Valle Del Cauca
# --> Origin : La Victoria, Valle Del Cauca
# --> Origin : Palmira, Valle Del Cauca
# --> Origin : Pradera, Valle Del Cauca
# --> Origin : Roldanillo, Valle Del Cauca
# --> Origin : Sevilla, Valle Del Cauca
# --> Origin : Tuluá, Valle Del Cauca
# --> Origin : Yumbo, Valle Del Cauca
# --> Origin : Zarzal, Valle Del Cauca
# --> Origin : Argelia, Valle Del Cauca
# --> Origin : Versalles, Valle Del Cauca
# --> Origin : El Cairo, Valle Del Cauca
# --> Origin : Obando, Valle Del Cauca
# --> Origin : Toro, Valle Del Cauca
# --> Origin : Bolívar, Valle Del Cauca
# --> Origin : El Dovio, Valle Del Cauca
# --> Origin : Riofrío, Valle Del Cauca
# --> Origin : Trujillo, Valle Del Cauca
# --> Origin : San Pedro, Valle Del Cauca
# --> Origin : Yotoco, Valle Del Cauca
# --> Origin : Calima, Valle Del Cauca
# --> Origin : Vijes, Valle Del Cauca
# --> Origin : Restrepo, Valle Del Cauca
#
#
# **** Processing departamento : Vaupés
# --> Origin : Mitú, Vaupés
# --> Origin : Carurú, Vaupés
# --> Origin : Pacoa, Vaupés
# --> Origin : Taraira, Vaupés
# --> Origin : Papunaua, Vaupés
# --> Origin : Yavaraté, Vaupés
#
#
# **** Processing departamento : Vichada
# --> Origin : Puerto Carreño, Vichada
# --> Origin : La Primavera, Vichada
# --> Origin : Cumaribo, Vichada
# --> Origin : Santa Rosalía, Vichada

# %%
df_ = pd.DataFrame()
for file in os.listdir(f'{output_files}/tmp'):
    df_ = pd.concat([df_, pd.read_csv(f'{output_files}/tmp/{file}')])

# %% [markdown]
# # Save file

# %%
df_.to_csv(f'{output_files}/travel_times_colombia_municipios.csv', index=False)

# %% [markdown]
# # Clean

# %%
def remove_directory_tree(start_directory: str):
    """Recursively and permanently removes the specified directory, all of its
    subdirectories, and every file contained in any of those folders."""
    for name in os.listdir(start_directory):
        path = os.path.join(start_directory, name)
        if os.path.isfile(path):
            os.remove(path)
        else:
            remove_directory_tree(path)
    os.rmdir(start_directory)
    
######################
## Remove old directories
######################
directory = f'{output_files}/tmp'
if os.path.exists(directory):
    try:
        #shutil.rmtree(directory)
        remove_directory_tree(directory)
        print("Directory '%s' has been removed successfully" %directory)
    except OSError as error:
        print(error)
        print("Directory '%s' can not be removed" %directory)
